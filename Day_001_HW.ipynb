# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
#homework 3
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(a,b):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum(a-b)**2 / len(a)
    return mse

# %%
def mean_absolute_error(a, b):
    mae  = sum(abs(a - b)) / len(b)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
Yplt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 6.108
# The Mean absolute error is 11.693

# %%
#homework 1 google landmark Recognition 2019
#1. 重要性：讓google增加對景點之辨識度
#2. 資料從何而來：網站上蒐集照片或實地拍攝，google map
#3. 照片，圖片
#4. 在看到特定照片時，可判斷位於哪個國家或是區域，旅遊網站或搜尋使用

# %%
#homework 2 自由載客車隊
#1.核心問題:如何提升業績
#1.1 選擇客流量大的路線=>搜尋附近景點、餐廳、娛樂
#1.2 選擇客流量大的時段=>假期、週五聚會、返鄉潮...
#1.3 特殊路線=>與大眾交通不同之路線，方便性

#2.資料從何而來
#2.1 蒐集該區域評價較高之餐廳、景點等娛樂地點或集散地 =>google地圖評價系統
#2.2 行事曆
#2.3 蒐集該區大眾交通等路線圖

#3.搜襲來的數據型態
#3.1 int
#3.2 time
#3.3 object

#4.如何評估
#4.1 評價越高越多人會去
#4.2 假期前後客流量比較大
#4.3 大眾運輸無抵達路線，景點，比較多人會選擇載客車隊前往
